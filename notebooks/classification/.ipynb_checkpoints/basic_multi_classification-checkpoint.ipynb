# %% [markdown]
# # Simple Multi-Class Example

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from matplotlib import cm
import seaborn as sns 

from matplotlib import cm
from tqdm.autonotebook import tqdm

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.calibration import CalibratedClassifierCV

from macest.classification import models as clmod
from macest.classification import utils as clut
from macest.classification import plots as clplot
from macest.classification.metrics import expected_calibration_error
from macest.model_selection import KFoldConfidenceSplit
# Out:
# /Users/Rhys/anaconda3/lib/python3.6/site-packages/tqdm/autonotebook.py:17: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   " (e.g. in jupyter console)", TqdmExperimentalWarning)

# %%
# sns.set_context("talk")
# sns.set_context("poster")
sns.set_context("notebook")
sns.set_style('darkgrid')

# %% [markdown]
# ### Functions to use for plotting further down

# %%
def plot_prediction_conf_surface(low_range, up_range, sklearn_model,
                                 plot_training_data = True):
    
    x1_ne = np.random.uniform(-low_range,low_range,10**4)
    x2_ne = np.random.uniform(-low_range,low_range,10**4)
    points_ne = np.array((x1_ne,x2_ne)).T

    x1_fa = np.random.uniform(-up_range,up_range,10**4)
    x2_fa = np.random.uniform(-up_range,up_range,10**4)
    points_fa = np.array((x1_fa,x2_fa)).T
    
    fig, ax = plt.subplots(ncols = 2, nrows =2,
                       figsize = (16,12),)

    h0 = ax[0,0].tricontourf(x1_ne,x2_ne, sklearn_model.predict(points_ne),
                             cmap = cm.get_cmap('rainbow', len(np.unique(y_pp_train))), 
                             alpha=.9)


    g0 = ax[0,1].tricontourf(x1_ne,x2_ne,
                             np.amax(sklearn_model.predict_proba(points_ne), axis =1), 
                             vmin=0.,
                             vmax =1,
                          cmap = cm.get_cmap('viridis'))
    
    if plot_training_data:

        ax[0,0].scatter(X_pp_train[:,0],X_pp_train[:,1], c=y_pp_train,
                      cmap = cm.rainbow,
                        edgecolors = 'black')
        ax[0,1].scatter(X_pp_train[:,0],X_pp_train[:,1],
                      c=y_pp_train,
                      cmap = cm.get_cmap('rainbow', len(np.unique(y_pp_train))),
                        edgecolors = 'black')


    h1 = ax[1,0].tricontourf(x1_fa,x2_fa, sklearn_model.predict(points_fa),
                             cmap = cm.get_cmap('rainbow', len(np.unique(y_pp_train))),
                             alpha=.9)
        
    ax[1,0].scatter(X_pp_train[:,0],X_pp_train[:,1],
                    c=y_pp_train,
                    edgecolors = 'black',
                    cmap = cm.get_cmap('rainbow', len(np.unique(y_pp_train))))


    g1 = ax[1,1].tricontourf(x1_fa,x2_fa,
                             np.amax(sklearn_model.predict_proba(points_fa), axis =1),
                             vmin=0.,
                             vmax=1.,
                             cmap = cm.viridis)
    
    ax[1,1].scatter(X_pp_train[:,0] ,X_pp_train[:,1],
                c=y_pp_train,
                alpha = 0.9,
                cmap = cm.get_cmap('rainbow', 4),
                edgecolors = 'black')
    
    fig.colorbar(h0, ax = [ax[0,0], ax[1,0]],
                 ticks= np.arange(0., len(np.unique(y_pp_train)) + 0.1, 1 ),
                 label = 'prediction')
    
    fig.colorbar(g1, ax = [ax[0,1], ax[1,1]],
             ticks= np.arange(0.0, 1.01, 0.1 ),
             label = 'Confidence')
    



    ax[0,0].set_xlabel('x1', fontsize = 18)
    ax[0,1].set_xlabel('x1', fontsize = 18)

    ax[0,0].set_ylabel('x2', fontsize = 18)
    ax[0,1].set_ylabel('x2', fontsize = 18)

    ax[1,0].set_xlabel('x1', fontsize = 18)
    ax[1,1].set_xlabel('x1', fontsize = 18)

    ax[1,0].set_ylabel('x2', fontsize = 18)
    ax[1,1].set_ylabel('x2', fontsize = 18)

# %%
def plot_macest_sklearn_comparison_surface(low_range, up_range ,
                                         macest_model, sklearn_model,
                                          plot_training_data = True):
    
    x1_ne = np.random.uniform(-low_range,low_range,10**4)
    x2_ne = np.random.uniform(-low_range,low_range,10**4)
    points_ne = np.array((x1_ne,x2_ne)).T

    x1_fa = np.random.uniform(-up_range,up_range,10**4)
    x2_fa = np.random.uniform(-up_range,up_range,10**4)
    points_fa = np.array((x1_fa,x2_fa)).T
    
    fig, ax = plt.subplots(ncols = 2, nrows =2,
                       figsize = (16,12),)
    
    h0 = ax[0,0].tricontourf(x1_ne,x2_ne,macest_model.predict_confidence_of_point_prediction(points_ne),
                             vmin=0.,
                             vmax =1,
                             cmap = cm.viridis)

    g0 = ax[0,1].tricontourf(x1_ne,x2_ne, np.amax(sklearn_model.predict_proba(points_ne), axis =1), 
                          vmin = 0.,
                          vmax =1,
                          cmap = cm.viridis)
    
    if plot_training_data :
        ax[0,0].scatter(X_pp_train[:,0],X_pp_train[:,1],
                        c=y_pp_train,
                        cmap = cm.rainbow,
                        edgecolors = 'black')

        ax[0,1].scatter(X_pp_train[:,0],X_pp_train[:,1],
                        c=y_pp_train, alpha = 0.9,
                        edgecolors = 'black',
                        cmap = cm.rainbow)


    h1 = ax[1,0].tricontourf(x1_fa,x2_fa,
                             macest_model.predict_confidence_of_point_prediction(points_fa),
                             vmin = 0.,
                             vmax =1,
                             cmap = cm.viridis)

    ax[1,0].scatter(X_pp_train[:,0],X_pp_train[:,1],
                    c=y_pp_train,
                    edgecolors = 'black', 
                    cmap = cm.get_cmap('rainbow', len(np.unique(y_pp_train))))

    g1 = ax[1,1].tricontourf(x1_fa,x2_fa,
                             np.amax(sklearn_model.predict_proba(points_fa), axis =1),
                             vmin = 0.,
                             vmax = 1.,
                             cmap = cm.viridis)

    ax[1,1].scatter(X_pp_train[:,0] ,X_pp_train[:,1],
                    c=y_pp_train,
                    alpha = 0.9,
                    cmap = cm.get_cmap('rainbow', len(np.unique(y_pp_train))),
                    edgecolors = 'black')
    
    fig.colorbar(h1,
                 ax=ax.ravel().tolist(), 
                 ticks= np.arange(0.,1.01, 0.1 ), 
                 label = 'Confidence')
    
    
    ax[0,0].set_title('MACE')
    ax[1,0].set_title('MACE')
    
    ax[0,1].set_title('Random Forest')
    ax[1,1].set_title('Random Forest')
        
    ax[0,0].set_xlabel('x1', fontsize = 18)
    ax[0,1].set_xlabel('x1', fontsize = 18)

    ax[0,0].set_ylabel('x2', fontsize = 18)
    ax[0,1].set_ylabel('x2', fontsize = 18)

    ax[1,0].set_xlabel('x1', fontsize = 18)
    ax[1,1].set_xlabel('x1', fontsize = 18)

    ax[1,0].set_ylabel('x2', fontsize = 18)
    ax[1,1].set_ylabel('x2', fontsize = 18)

# %% [markdown]
# ### Functions to generate the multi-class star

# %%
def make_funky_star(n_arms, n_points):
    arms = n_arms
    points_per_arm = int(n_points/arms)
    angs = np.arange(np.pi/arms, np.pi + 0.001, np.pi/arms)
    cov = np.array([[6, 5.93], [5.93, 6]])
    a = np.random.multivariate_normal((0,0), 
                                      cov,
                                      points_per_arm)
    arms = []
    for theta in angs:
        c, s = np.cos(theta), np.sin(theta)
        R = np.array(((c,-s), (s, c)))
        arms.append(R.dot(a.T).T)
    
    star = np.vstack(arms)
    return star

# %%
def make_star_classes(n_arms, n_points, n_classes):
    n_points_per_arm = int(n_points/n_classes)
    y = np.zeros((int(n_arms) ,int(n_points_per_arm)))
    for i in range(n_arms):
        j = np.mod(i, n_classes)
        y[i, :] = j * np.ones(int(n_points_per_arm))
    y = y.flatten()
    return y

# %%
n_arms = 4
n_points = 4 *10**4
n_classes = 4
n_points_per_arm = n_points/(n_arms)

# %%
X = make_funky_star(n_arms, n_points)

# %%
y = make_star_classes(n_arms, n_points, n_classes)

# %%
y = y.astype(int)

# %%
plt.figure(figsize = (8,6))
plt.scatter(X[:,0], X[:,1], c = y,cmap = cm.rainbow, edgecolors='black')
plt.xlabel('x1', fontsize = 18)
plt.ylabel('x2', fontsize = 18)
# plt.legend()
# Out:
# Text(0, 0.5, 'x2')

# %% [markdown]
# ## We need to split the data into four sets,
# 1. The training data for the point prediction model
# 2. data used to build a graph of known labelled data for the confidence model
# 3. Data to calibrate MACE parameters
# 4. Unseen testing data

# %%
X_pp_train, X_conf_train, y_pp_train, y_conf_train  = train_test_split(X, y, test_size=0.6, random_state=0)
X_conf_train, X_cal, y_conf_train, y_cal = train_test_split(X_conf_train, y_conf_train,
                                                            test_size=0.4, random_state=0)
X_cal, X_test, y_cal,  y_test, = train_test_split(X_cal, y_cal, test_size=0.4, random_state=0)

# %% [markdown]
# ## Train a point prediction model

# %%
model = RandomForestClassifier(n_estimators = 100, random_state=0)
model.fit(X_pp_train, y_pp_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
print(model.score(X_conf_train, y_conf_train))
print(model.score(X_cal, y_cal))
# Out:
# 0.8655555555555555
# 0.8640625

# %% [markdown]
# ## Let's train MACE, In the cell below we will specify the hnsw args which will define our notion of similarity and the graph/search parameters

# %%
macest_model = clmod.ModelWithConfidence(model,
                                      X_conf_train,
                                      y_conf_train)

macest_model.fit(X_cal, y_cal)
# Out:
# ...
#
# min_loss = 0.12400595595066857
# best_alpha: 33.40048340701203
# best_beta: 1.0000000000546698
# best_k: 16.0
# best_Temp: 1.0186325551100552

# %% [markdown]
# #### We can change the MACE defaults if we want as shown below by editing the NamedTuple for each parameter

# %%
clmod.SearchBounds()
# Out:
# SearchBounds(alpha_bounds=(0.1, 50), beta_bounds=(1.0, 1.0000000001), k_bounds=(5, 40), temperature_bounds=(0, 25))

# %%
clmod.HnswGraphArgs()
# Out:
# HnswGraphArgs(init_args={'method': 'hnsw', 'space': 'l2'}, construction_args={'post': 2, 'efConstruction': 1000, 'M': 100}, query_args={'ef': 1000})

# %%
param_bounds = clmod.SearchBounds(k_bounds = (5,15))
neighbour_search_params = clmod.HnswGraphArgs(query_args = dict(ef = 1100))

# %% [markdown]
# #### Optimiser args are the arguments passed to scipy differential evolution and must be passed as a dictionary

# %%
optimiser_args = dict(popsize = 15)

# %%
macest_model = clmod.ModelWithConfidence(model,
                                      X_conf_train,
                                      y_conf_train, 
                                      search_method_args =neighbour_search_params)

macest_model.fit(X_cal,
               y_cal,
               param_range = param_bounds,
               optimiser_args = optimiser_args)
# Out:
# ...
#
# min_loss = 0.15685830590389913
# best_alpha: 42.96333496305911
# best_beta: 1.0000000000151443
# best_k: 14.0
# best_Temp: 1.0127019043430554

# %% [markdown]
# ### In the plot below we see that the random forest model partitions the space into 4 classes, this partitioning is effective very close to the data however does not make much sense elsewhere, i.e. at ~10 degrees away from the vertical the model predicts red with very high confidence
# ### This partitioning also means that confidence does not decrease far away from the data as the confidence is also effectively partitioned

# %%
plot_prediction_conf_surface(20, 202, model)

# %% [markdown]
# ### Partitioning the space effectively learns a global model, MACE is fundamentally different in that it treats confidence as a local quantity, this is apparent in the bottom plot when we try to extrapolate away from the data

# %% [markdown]
# ### MACE confidence (as default) shows the confidence that the point prediction is correct, this is not necessarily the max MACE confidence score however we believe that this is a more useful metric as MACE is not designed to be a classifer (and in general will likely not perform as well globally as other classifiers), it is meant to be used to indicate how much one should trust a point prediction.
# An example of this can be seen below, the model only predicts blue for a very thin slice, either side of this strip it predicts a different class, so the MACE confidence score is almost 0 implying it thinks it's more likely that it's a different class. A confidence score this low would indicate that this prediction is strange in some way

# %%
plot_macest_sklearn_comparison_surface(20,
                                     202,
                                     macest_model,
                                     model,
                                     plot_training_data=True)

# %% [markdown]
# ## Let's observe the effect of changing the similarity metric

# %% [markdown]
# ## L1

# %%
neighbour_search_params = clmod.HnswGraphArgs(init_args = dict(method = 'hnsw', 
                                                              space = 'l1'))

# %%
macest_model = clmod.ModelWithConfidence(model,
                                      X_conf_train,
                                      y_conf_train, 
                                      search_method_args = neighbour_search_params)

macest_model.fit(X_cal, y_cal, param_range = param_bounds, optimiser_args= optimiser_args)
# Out:
# ...
#
# min_loss = 0.1917710999376546
# best_alpha: 28.5716610277428
# best_beta: 1.0000000000933928
# best_k: 9.0
# best_Temp: 0.9085009323952065

# %%
plot_prediction_conf_surface(20, 202, model)

# %%
plot_macest_sklearn_comparison_surface(20, 202, macest_model, model, plot_training_data=True)

# %% [markdown]
# ## Cosine

# %% [markdown]
# ### Cosine similarity is useful if we believe that data points are similar if they have the same angle, i.e. if they point in the same direction. The length of this vector is not important

# %%
neighbour_search_params = clmod.HnswGraphArgs(init_args = dict(method = 'hnsw', 
                                                              space = 'cosinesimil'))

# %%
macest_model = clmod.ModelWithConfidence(model,
                                      X_conf_train,
                                      y_conf_train, 
                                      search_method_args = neighbour_search_params)

macest_model.fit(X_cal, y_cal, param_range = param_bounds, optimiser_args= optimiser_args)
# Out:
# ...
#
# min_loss = 5.733923826383631
# best_alpha: 49.49315781854713
# best_beta: 1.0000000000814815
# best_k: 14.0
# best_Temp: 0.6214926308039455

# %%
plot_prediction_conf_surface(20, 202, model)

# %%
plot_macest_sklearn_comparison_surface(20, 202, macest_model, model, plot_training_data=True)

# %% [markdown]
# ### Angular Distance

# %% [markdown]
# ### Angular distance is very similar to the cosine distance however it is transformed such that it's a proper metric

# %%
neighbour_search_params = clmod.HnswGraphArgs(init_args = dict(method = 'hnsw', 
                                                              space = 'angulardist'))

# %%
macest_model = clmod.ModelWithConfidence(model,
                                      X_conf_train,
                                      y_conf_train, 
                                      search_method_args = neighbour_search_params)

macest_model.fit(X_cal, y_cal, param_range = param_bounds, optimiser_args= optimiser_args)
# Out:
# ...
#
# min_loss = 4.95449765747147
# best_alpha: 41.13669261318385
# best_beta: 1.0000000000179807
# best_k: 14.0
# best_Temp: 0.4214335268102367

# %%
plot_prediction_conf_surface(20, 202, model)

# %%
plot_macest_sklearn_comparison_surface(20, 202, macest_model, model, plot_training_data=True)

# %% [markdown]
# ### If we Wanted to go K fold with MACE we need to use the modified Kfold to ensure that the 4 splits are done correctly
# #### the default is to use 1./nsplits as test data, then of the remaining data split that  as
# 1. 50% point pre
# 2. 30% To build graph
# 3. 20% to calibrate MACE parameters

# %%
kfold = KFoldConfidenceSplit(n_splits =5, shuffle = True)

# %%
n_arms = 4
n_points = 10**3
n_classes = 4

# %%
X = make_funky_star(n_arms = 4,
                    n_points= n_points)

y = make_star_classes(n_arms=4,
                      n_points=n_points,
                      n_classes= 4)
y = y.astype(int)

# %%
ece = []

for train_idxs, conf_cal_idxs, conf_graph_idxs, test_idxs in kfold.split(X):
        
    X_pp_train = X[train_idxs]
    y_pp_train =  y[train_idxs]
    
    X_test = X[test_idxs]
    y_test = y[test_idxs]
    
    X_cal = X[conf_cal_idxs]
    y_cal = y[conf_cal_idxs]
    
    X_graph = X[conf_graph_idxs]
    y_graph = y[conf_graph_idxs]
    

    model = RandomForestClassifier(random_state =0,
                               n_estimators =500)
    
    model.fit(X_pp_train, y_pp_train)
    
    model_preds = model.predict(X_test)    
    macest_model = clmod.ModelWithConfidence(model,
                                      X_graph,
                                      y_graph)
    

    macest_model.fit(X_cal, y_cal)
    ece.append(expected_calibration_error(model_preds,
                                          y_test,
                                          macest_model.predict_confidence_of_point_prediction(X_test)))
# Out:
# ...
#
# min_loss = 0.12472917223863991
# best_alpha: 6.653532747559204
# best_beta: 1.0000000000787166
# best_k: 5.0
# best_Temp: 4.0102252229794075
# ...
#
# min_loss = 2.434387199662917
# best_alpha: 5.362822201227814
# best_beta: 1.0000000000629274
# best_k: 6.0
# best_Temp: 3.8306554636250745
# ...
#
# min_loss = 1.6151828782693132
# best_alpha: 1.1798904123836405
# best_beta: 1.0000000001
# best_k: 5.0
# best_Temp: 25.0
# ...
#
# min_loss = 2.4473971214032337
# best_alpha: 18.390791538074065
# best_beta: 1.0000000000787093
# best_k: 8.0
# best_Temp: 5.466729896393034
# ...
#
# min_loss = 2.2464517209924835
# best_alpha: 7.912143159711924
# best_beta: 1.000000000069645
# best_k: 6.0
# best_Temp: 3.353309600709863

# %%
sns.boxplot(ece)
plt.xlabel('ECE')
# Out:
# Text(0.5, 0, 'ECE')
