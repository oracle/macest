# %% [markdown]
# # California Bike Sharing

# %%
# %load_ext autoreload
# %autoreload 2}

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 

from matplotlib import cm

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import scale

from macest.regression import models as reg_mod
from macest.regression import plots as reg_plot
from macest.model_selection import KFoldConfidenceSplit

# %%
sns.set_style('darkgrid')
sns.set_context('notebook')

# %% [markdown]
# ## Load (cleaned and pre-processed) data

# %%
bike_df = pd.read_csv('../../data/bike_df.csv').sample(frac=1)
bike_df.reset_index(drop=True, inplace=True)
# bike_df = bike_df.sample(frac=1)
y = bike_df['cnt'].values
X = bike_df.drop('cnt', axis =1).values

# %%
## Split the data into 4 groups

# %% [markdown]
# ## Split the data into 4 groups

# %%
X_pp_train, X_conf_train, y_pp_train, y_conf_train  = train_test_split(X,
                                                                       y,
                                                                       test_size=0.66,
                                                                       random_state=10)

X_conf_train, X_cal, y_conf_train, y_cal = train_test_split(X_conf_train, y_conf_train,
                                                            test_size=0.5, random_state=1)
X_cal, X_test, y_cal,  y_test, =  train_test_split(X_cal, y_cal, test_size=0.5, random_state=1)

# %%
bike_df.shape
# Out:
# (17379, 13)

# %%
print(X_pp_train.shape)
print(X_conf_train.shape)
print(X_cal.shape)
print(X_test.shape)
# Out:
# (5908, 12)
# (5735, 12)
# (2868, 12)
# (2868, 12)

# %% [markdown]
# ## Train a point prediction model

# %%
rf_bike = RandomForestRegressor(random_state =1, n_estimators = 200)
rf_bike.fit(X_pp_train, y_pp_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=200,
#                       n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                       warm_start=False)

# %%
rf_bike.score(X_test, y_test)
# Out:
# 0.92931505514813

# %%
rf_preds = rf_bike.predict(X_conf_train)

# %%
test_error = abs(rf_preds - y_conf_train)

# %%
search_args = reg_mod.HnswGraphArgs(query_args= {'ef': 1500})
bnds = reg_mod.SearchBounds(k_bounds = (5,30))

# %% [markdown]
# ## Initialise and fit MACE

# %%
macest_model = reg_mod.ModelWithPredictionInterval(
        rf_bike,
        X_conf_train,
        test_error,
        error_dist='laplace',
        dist_func='linear', 
        search_method_args = search_args)

# %%
optimiser_args = dict(popsize = 20, disp= False)

# %%
macest_model.fit(X_cal,
               y_cal,
               param_range= bnds,
               optimiser_args = optimiser_args)
# Out:
# min_loss = 0.266387726638775
# best_alpha: 3.6363033239246434
# best_beta: 0.5714240548550116
# best_k: 21

# %% [markdown]
# ## Calibration data

# %%
reg_plot.plot_calibration(macest_model, X_cal, y_cal)
# Out:
# 10th percentile
# percentage of values inside of interval 10%
# 30th percentile
# percentage of values inside of interval 31%
# 50th percentile
# percentage of values inside of interval 50%
# 70th percentile
# percentage of values inside of interval 70%
# 90th percentile
# percentage of values inside of interval 90%
# 95th percentile
# percentage of values inside of interval 95%

# %%
reg_plot.plot_true_vs_actual(rf_bike, macest_model, X_cal, y_cal)

# %%
reg_plot.plot_actual_vs_true(rf_bike, macest_model, X_cal, y_cal)

# %% [markdown]
# ## Unseen

# %%
reg_plot.plot_calibration(macest_model, X_test, y_test)
# Out:
# 10th percentile
# percentage of values inside of interval 10%
# 30th percentile
# percentage of values inside of interval 31%
# 50th percentile
# percentage of values inside of interval 50%
# 70th percentile
# percentage of values inside of interval 69%
# 90th percentile
# percentage of values inside of interval 89%
# 95th percentile
# percentage of values inside of interval 95%

# %%
reg_plot.plot_true_vs_actual(rf_bike, macest_model, X_test, y_test)

# %%
reg_plot.plot_actual_vs_true(rf_bike, macest_model, X_test, y_test)
